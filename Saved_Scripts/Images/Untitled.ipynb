# %%
import base64

# Convert image to base64 string
def image_to_base64(img_path):
    with open(img_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

img_path = "C:/Users/samhs/Jupyter(DataBackup)/Images/Login.png" # replace with your image path
img_base64_str = image_to_base64(img_path)

# If you want to display the image in the notebook:
img_data = base64.b64decode(img_base64_str)
display.display(Image(data=img_data))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 13
#      11 # If you want to display the image in the notebook:
#      12 img_data = base64.b64decode(img_base64_str)
# ---> 13 display.display(Image(data=img_data))
#
# AttributeError: 'function' object has no attribute 'display'

# %%
print(f'![Image description](data:image/png;base64,{img_base64_str})')
# Out:
# ![Image description](data:image/png;base64,...)
